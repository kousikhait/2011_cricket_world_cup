# %%
#from google.colab import files
#uploaded=files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mr = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Most Runs.xlsx")
mr
# Out:
#            Player  Highest Score  Matches  RUNS  Average
# 0      TM Dilshan            144        9   500    62.50
# 1    SR Tendulkar            120        9   482    53.55
# 2   KC Sangakkara            111        9   465    93.00
# 3       IJL Trott             92        7   422    60.28
# 4     WU Tharanga            133        9   395    56.42
# 5       G Gambhir             97        9   393    43.66
# 6        V Sehwag            175        8   380    47.50
# 7         Y Singh            113        9   362    90.50
# 8  AB de Villiers            134        5   353    88.25
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# mr['Highest Score'].plot(kind='hist', bins=20, title='Highest Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# mr['Matches'].plot(kind='hist', bins=20, title='Matches')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# mr['RUNS'].plot(kind='hist', bins=20, title='RUNS')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# mr['Average'].plot(kind='hist', bins=20, title='Average')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# mr.plot(kind='scatter', x='Highest Score', y='Matches', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# mr.plot(kind='scatter', x='Matches', y='RUNS', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# mr.plot(kind='scatter', x='RUNS', y='Average', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# mr['Highest Score'].plot(kind='line', figsize=(8, 4), title='Highest Score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# mr['Matches'].plot(kind='line', figsize=(8, 4), title='Matches')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# mr['RUNS'].plot(kind='line', figsize=(8, 4), title='RUNS')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# mr['Average'].plot(kind='line', figsize=(8, 4), title='Average')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = 'Player',y = 'RUNS',data = mr)
plt.show()

# %%
mw = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Most Wickets.xlsx")
mw
# Out:
#           Player  Matches  Wickets
# 0         Z Khan        9       21
# 1       S Afridi        8       21
# 2     TG Southee        8       18
# 3    RJ Peterson        7       15
# 4  M Murlitharan        9       15
# 5        Y Singh        9       15
# 6        I Tahir        5       14
# 7          U Gul        8       14
# 8        K Roach        6       13

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = 'Player',y = 'Wickets',data = mw)
plt.show()

# %%
hs = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Highest Scores.xlsx")
hs
# Out:
#             Player   Score      Opponent
# 0          V Sehwag     175   Bangladesh
# 1        AJ Strauss     158        India
# 2        TM Dilshan     144     Zimbabwe
# 3    AB de Villiers     134  Netherlands
# 4       WU Tharanga     133     Zimbabwe
# 5       LRPL Taylor     131     Pakistan
# 6      SR Tendulkar     120      England
# 7  RN ten Doeschate     119      England
# 8      KJ  O'Brien      113      England

# %%
# plt.figure(figsize=(15,10))
# sns.barplot(x = 'Player',y = 'Score',data = hs)
# plt.show()
#  plt.figure(figsize=(15,10))
# sns.barplot(hs["Player "],hs["Score "]);
plt.figure(figsize=(15,10))
sns.barplot(x = 'Player ',y = 'Score ',data = hs)
plt.show()

# %%
sc = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Stadium CAPACITY.xlsx")
sc
# Out:
#                            Stadium     Country       Place  Capacity
# 0                     Eden Gardens       India     Kolkata     66349
# 1         M.A. Chidambaram Stadium       India     Chennai     50000
# 2         Feroz Shah Kotla Stadium       India       Delhi     41820
# 3             Sardar Patel Stadium       India   Ahmedabad     54000
# 4        Vidharbha Cricket Stadium       India      Nagpur     45000
# 5                 Wankhede Stadium       India      Mumbai     33108
# 6           Punjab Cricket Stadium       India      Mohali     26950
# 7           M. Chinnaswamy Stadium       India   Bengaluru     40000
# 8              R. Premdasa Stadium   Sri Lanka     Colombo     35000
# 9                Pallekele Stadium   Sri Lanka   Pallekele     35000
# 10       Mahinda Rajapaksa Stadium   Sri Lanka  Hambantota     35000
# 11  Zorur Ahemed Chowdhury Stadium  Bangladesh  Chittagong     20000
# 12           Sher-e-Bangla Stadium  Bangladesh       Dhaka     26000

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = 'Place',y = 'Capacity',data = sc)
plt.show()

# %%
ga = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Group A Standings.xlsx")
ga
# Out:
#    Position         Team  Played  Won  Lost   No Result
# 0         1     Pakistan       6    5     1           0
# 1         2    Sri Lanka       6    4     1           1
# 2         3    Australia       6    4     1           1
# 3         4  New Zealand       6    4     2           0
# 4         5     Zimbabwe       6    2     4           0
# 5         6       Canada       6    1     5           0
# 6         7        Kenya       6    0     6           0

# %%
gas = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Group Matches.xlsx")
gas
# Out:
#    Match no.              Match played  First Innings Score  \
# 0    Match 1      Kenya vs New Zealand                   69
# 1    Match 2       Sri Lanka vs Canada                  332
# 2    Match 3     Australia vs Zimbabwe                  262
# 3    Match 4         Pakistan vs Kenya                  317
# 4    Match 5  New Zealand vs Australia                  206
# 5    Match 6     Pakistan vs Sri Lanka                  277
# 6    Match 7        Zimbabwe vs Canada                  298
# 7    Match 8        Kenya vs Sri Lanka                  142
# 8    Match 9        Pakistan vs Canada                  184
# 9   Match 10   Zimbabwe vs New Zealand                  162
# 10  Match 11    Sri Lanka vs Australia                  146
# 11  Match 12           Kenya vs Canada                  198
# 12  Match 13   New Zealand vs Pakistan                  302
# 13  Match 14     Sri Lanka vs Zimbabwe                  327
# 14  Match 15     New Zealand vs Canada                  358
# 15  Match 16        Australia vs Kenya                  324
# 16  Match 17      Zimbabwe vs Pakistan                  151
# 17  Match 18       Canada vs Australia                  211
# 18  Match 19  Sri Lanka vs New Zealand                  265
# 19  Match 20     Australia vs Pakistan                  176
# 20  Match 21         Zimbabwe vs Kenya                  308
#
#     Second Innings Score  Overs played 1  Overs played 2  \
# 0                   72.0            23.5             8.0
# 1                  122.0            50.0            36.5
# 2                  171.0            50.0            46.2
# 3                  112.0            50.0            33.1
# 4                  207.0            45.1            34.0
# 5                  266.0            50.0            50.0
# 6                  123.0            50.0            42.1
# 7                  146.0            43.4            18.4
# 8                  138.0            43.0            42.5
# 9                  166.0            46.2            33.3
# 10                   NaN            32.5             NaN
# 11                 199.0            50.0            45.3
# 12                 192.0            50.0            41.4
# 13                 188.0            50.0            39.0
# 14                 261.0            50.0            50.0
# 15                 264.0            50.0            50.0
# 16                 164.0            39.4            34.1
# 17                 212.0            45.4            34.5
# 18                 153.0            50.0            35.0
# 19                 178.0            46.4            41.0
# 20                 147.0            50.0            36.0
#
#     Wickets fell(1st Innings)  Wickets fell(2nd Innings)     Stadium
# 0                          10                        0.0     Chennai
# 1                           7                       10.0  Hambantota
# 2                           6                       10.0   Ahmedabad
# 3                           7                       10.0  Hambantota
# 4                          10                        3.0      Nagpur
# 5                           7                        9.0     Colombo
# 6                           9                       10.0      Nagpur
# 7                          10                        1.0     Colombo
# 8                          10                       10.0     Colombo
# 9                          10                        0.0   Ahmedabad
# 10                          3                        NaN     Colombo
# 11                         10                        5.0       Delhi
# 12                          7                       10.0   Pallekele
# 13                          6                       10.0   Pallekele
# 14                          6                        9.0      Mumbai
# 15                          6                        6.0   Bengaluru
# 16                          7                        3.0   Pallekele
# 17                         10                        3.0   Bengaluru
# 18                          9                       10.0      Mumbai
# 19                         10                        6.0     Colombo
# 20                          6                       10.0     Kolkata

# %%
gas["First Innings Score"].describe()
# Out:
# count     21.000000
# mean     238.809524
# std       80.591947
# min       69.000000
# 25%      176.000000
# 50%      262.000000
# 75%      308.000000
# max      358.000000
# Name: First Innings Score, dtype: float64

# %%
density = np.array([gas["First Innings Score"]])


sns.set(rc={'figure.figsize':(15.7,6.27)})
plt.title("Density Distribuition of 1st innings scores")
sns.distplot(density, hist=True, rug=True);
# Out:
# <ipython-input-15-066f5f0a357a>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(density, hist=True, rug=True);

# %%
#Run rate of 1st innings
gas["run_rate_1"] = gas["First Innings Score"]/gas["Overs played 1"]
gas
# Out:
#    Match no.              Match played  First Innings Score  \
# 0    Match 1      Kenya vs New Zealand                   69
# 1    Match 2       Sri Lanka vs Canada                  332
# 2    Match 3     Australia vs Zimbabwe                  262
# 3    Match 4         Pakistan vs Kenya                  317
# 4    Match 5  New Zealand vs Australia                  206
# 5    Match 6     Pakistan vs Sri Lanka                  277
# 6    Match 7        Zimbabwe vs Canada                  298
# 7    Match 8        Kenya vs Sri Lanka                  142
# 8    Match 9        Pakistan vs Canada                  184
# 9   Match 10   Zimbabwe vs New Zealand                  162
# 10  Match 11    Sri Lanka vs Australia                  146
# 11  Match 12           Kenya vs Canada                  198
# 12  Match 13   New Zealand vs Pakistan                  302
# 13  Match 14     Sri Lanka vs Zimbabwe                  327
# 14  Match 15     New Zealand vs Canada                  358
# 15  Match 16        Australia vs Kenya                  324
# 16  Match 17      Zimbabwe vs Pakistan                  151
# 17  Match 18       Canada vs Australia                  211
# 18  Match 19  Sri Lanka vs New Zealand                  265
# 19  Match 20     Australia vs Pakistan                  176
# 20  Match 21         Zimbabwe vs Kenya                  308
#
#     Second Innings Score  Overs played 1  Overs played 2  \
# 0                   72.0            23.5             8.0
# 1                  122.0            50.0            36.5
# 2                  171.0            50.0            46.2
# 3                  112.0            50.0            33.1
# 4                  207.0            45.1            34.0
# 5                  266.0            50.0            50.0
# 6                  123.0            50.0            42.1
# 7                  146.0            43.4            18.4
# 8                  138.0            43.0            42.5
# 9                  166.0            46.2            33.3
# 10                   NaN            32.5             NaN
# 11                 199.0            50.0            45.3
# 12                 192.0            50.0            41.4
# 13                 188.0            50.0            39.0
# 14                 261.0            50.0            50.0
# 15                 264.0            50.0            50.0
# 16                 164.0            39.4            34.1
# 17                 212.0            45.4            34.5
# 18                 153.0            50.0            35.0
# 19                 178.0            46.4            41.0
# 20                 147.0            50.0            36.0
#
#     Wickets fell(1st Innings)  Wickets fell(2nd Innings)     Stadium  \
# 0                          10                        0.0     Chennai
# 1                           7                       10.0  Hambantota
# 2                           6                       10.0   Ahmedabad
# 3                           7                       10.0  Hambantota
# 4                          10                        3.0      Nagpur
# 5                           7                        9.0     Colombo
# 6                           9                       10.0      Nagpur
# 7                          10                        1.0     Colombo
# 8                          10                       10.0     Colombo
# 9                          10                        0.0   Ahmedabad
# 10                          3                        NaN     Colombo
# 11                         10                        5.0       Delhi
# 12                          7                       10.0   Pallekele
# 13                          6                       10.0   Pallekele
# 14                          6                        9.0      Mumbai
# 15                          6                        6.0   Bengaluru
# 16                          7                        3.0   Pallekele
# 17                         10                        3.0   Bengaluru
# 18                          9                       10.0      Mumbai
# 19                         10                        6.0     Colombo
# 20                          6                       10.0     Kolkata
#
#     run_rate_1
# 0     2.936170
# 1     6.640000
# 2     5.240000
# 3     6.340000
# 4     4.567627
# 5     5.540000
# 6     5.960000
# 7     3.271889
# 8     4.279070
# 9     3.506494
# 10    4.492308
# 11    3.960000
# 12    6.040000
# 13    6.540000
# 14    7.160000
# 15    6.480000
# 16    3.832487
# 17    4.647577
# 18    5.300000
# 19    3.793103
# 20    6.160000

# %%
gas["run_rate_1"].describe()
# Out:
# count    21.000000
# mean      5.080320
# std       1.261578
# min       2.936170
# 25%       3.960000
# 50%       5.240000
# 75%       6.160000
# max       7.160000
# Name: run_rate_1, dtype: float64

# %%
# plt.figure(figsize=(15,10))
# sns.barplot(gas["Stadium"],gas["run_rate_1"]);
plt.figure(figsize=(15,10))
sns.barplot(x = 'Stadium',y = 'run_rate_1',data = gas)
plt.show()

# %%
density = np.array([gas["run_rate_1"]])


sns.set(rc={'figure.figsize':(15,6.27)})
plt.title("Density Distribuition of 1st innings run_rates")
sns.distplot(density, hist=True, rug=True);
# Out:
# <ipython-input-19-4c86e3726bf3>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(density, hist=True, rug=True);

# %%
gas["Wickets fell(1st Innings)"].describe()
# Out:
# count    21.000000
# mean      7.904762
# std       2.047065
# min       3.000000
# 25%       6.000000
# 50%       7.000000
# 75%      10.000000
# max      10.000000
# Name: Wickets fell(1st Innings), dtype: float64

# %%
plt.figure(figsize=(22,10))
plt.title("Graph of wickets fell in 1st innings")
sns.barplot(x = 'Match no.',y = 'Wickets fell(1st Innings)',data = gas)
plt.show()

# %%
gas["Overs played 1"].describe()
# Out:
# count    21.000000
# mean     45.947619
# std       6.859783
# min      23.500000
# 25%      45.100000
# 50%      50.000000
# 75%      50.000000
# max      50.000000
# Name: Overs played 1, dtype: float64

# %%
plt.figure(figsize=(22,10))
plt.title("Graph of wickets fell in 1st innings")
sns.barplot(x = 'Match no.',y = 'Overs played 1',data = gas)
plt.show()

# %%
gas["Second Innings Score"].describe()
# Out:
# count     20.000000
# mean     174.050000
# std       51.709182
# min       72.000000
# 25%      144.000000
# 50%      168.500000
# 75%      201.000000
# max      266.000000
# Name: Second Innings Score, dtype: float64

# %%
density = np.array([gas["Second Innings Score"]])


sns.set(rc={'figure.figsize':(15.7,6.27)})
plt.title("Density Distribuition of 2nd innings scores")
sns.distplot(density, hist=True, rug=True);
# Out:
# <ipython-input-25-96a9b6bac5ba>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(density, hist=True, rug=True);

# %%
#Run rate of 2nd innings
gas["run_rate_2"] = gas["Second Innings Score"]/gas["Overs played 2"]
gas
# Out:
#    Match no.              Match played  First Innings Score  \
# 0    Match 1      Kenya vs New Zealand                   69
# 1    Match 2       Sri Lanka vs Canada                  332
# 2    Match 3     Australia vs Zimbabwe                  262
# 3    Match 4         Pakistan vs Kenya                  317
# 4    Match 5  New Zealand vs Australia                  206
# 5    Match 6     Pakistan vs Sri Lanka                  277
# 6    Match 7        Zimbabwe vs Canada                  298
# 7    Match 8        Kenya vs Sri Lanka                  142
# 8    Match 9        Pakistan vs Canada                  184
# 9   Match 10   Zimbabwe vs New Zealand                  162
# 10  Match 11    Sri Lanka vs Australia                  146
# 11  Match 12           Kenya vs Canada                  198
# 12  Match 13   New Zealand vs Pakistan                  302
# 13  Match 14     Sri Lanka vs Zimbabwe                  327
# 14  Match 15     New Zealand vs Canada                  358
# 15  Match 16        Australia vs Kenya                  324
# 16  Match 17      Zimbabwe vs Pakistan                  151
# 17  Match 18       Canada vs Australia                  211
# 18  Match 19  Sri Lanka vs New Zealand                  265
# 19  Match 20     Australia vs Pakistan                  176
# 20  Match 21         Zimbabwe vs Kenya                  308
#
#     Second Innings Score  Overs played 1  Overs played 2  \
# 0                   72.0            23.5             8.0
# 1                  122.0            50.0            36.5
# 2                  171.0            50.0            46.2
# 3                  112.0            50.0            33.1
# 4                  207.0            45.1            34.0
# 5                  266.0            50.0            50.0
# 6                  123.0            50.0            42.1
# 7                  146.0            43.4            18.4
# 8                  138.0            43.0            42.5
# 9                  166.0            46.2            33.3
# 10                   NaN            32.5             NaN
# 11                 199.0            50.0            45.3
# 12                 192.0            50.0            41.4
# 13                 188.0            50.0            39.0
# 14                 261.0            50.0            50.0
# 15                 264.0            50.0            50.0
# 16                 164.0            39.4            34.1
# 17                 212.0            45.4            34.5
# 18                 153.0            50.0            35.0
# 19                 178.0            46.4            41.0
# 20                 147.0            50.0            36.0
#
#     Wickets fell(1st Innings)  Wickets fell(2nd Innings)     Stadium  \
# 0                          10                        0.0     Chennai
# 1                           7                       10.0  Hambantota
# 2                           6                       10.0   Ahmedabad
# 3                           7                       10.0  Hambantota
# 4                          10                        3.0      Nagpur
# 5                           7                        9.0     Colombo
# 6                           9                       10.0      Nagpur
# 7                          10                        1.0     Colombo
# 8                          10                       10.0     Colombo
# 9                          10                        0.0   Ahmedabad
# 10                          3                        NaN     Colombo
# 11                         10                        5.0       Delhi
# 12                          7                       10.0   Pallekele
# 13                          6                       10.0   Pallekele
# 14                          6                        9.0      Mumbai
# 15                          6                        6.0   Bengaluru
# 16                          7                        3.0   Pallekele
# 17                         10                        3.0   Bengaluru
# 18                          9                       10.0      Mumbai
# 19                         10                        6.0     Colombo
# 20                          6                       10.0     Kolkata
#
#     run_rate_1  run_rate_2
# 0     2.936170    9.000000
# 1     6.640000    3.342466
# 2     5.240000    3.701299
# 3     6.340000    3.383686
# 4     4.567627    6.088235
# 5     5.540000    5.320000
# 6     5.960000    2.921615
# 7     3.271889    7.934783
# 8     4.279070    3.247059
# 9     3.506494    4.984985
# 10    4.492308         NaN
# 11    3.960000    4.392936
# 12    6.040000    4.637681
# 13    6.540000    4.820513
# 14    7.160000    5.220000
# 15    6.480000    5.280000
# 16    3.832487    4.809384
# 17    4.647577    6.144928
# 18    5.300000    4.371429
# 19    3.793103    4.341463
# 20    6.160000    4.083333

# %%
gas["run_rate_2"].describe()
# Out:
# count    20.000000
# mean      4.901290
# std       1.518639
# min       2.921615
# 25%       3.987825
# 50%       4.723533
# 75%       5.290000
# max       9.000000
# Name: run_rate_2, dtype: float64

# %%
plt.figure(figsize=(15,10))
# sns.barplot(gas["Stadium"],gas["run_rate_2"]);
sns.barplot(x = 'Stadium',y = 'run_rate_2',data = gas)
plt.show()

# %%
gas["Wickets fell(2nd Innings)"].describe()
# Out:
# count    20.000000
# mean      6.750000
# std       3.809614
# min       0.000000
# 25%       3.000000
# 50%       9.000000
# 75%      10.000000
# max      10.000000
# Name: Wickets fell(2nd Innings), dtype: float64

# %%
plt.figure(figsize=(22,10))
plt.title("Graph of wickets fell in 2nd innings")
# sns.barplot(gas["Match no."],gas["Wickets fell(2nd Innings)"]);
sns.barplot(x = 'Match no.',y = 'Wickets fell(2nd Innings)',data = gas)
plt.show()

# %%
gas["Overs played 2"].describe()
# Out:
# count    20.000000
# mean     37.520000
# std      10.248266
# min       8.000000
# 25%      34.075000
# 50%      37.750000
# 75%      43.200000
# max      50.000000
# Name: Overs played 2, dtype: float64

# %%
ta = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Grp A toss.xlsx")
ta
# Out:
#    Match no. Won the toss Decision Won the match
# 0    Match 1        Kenya      Bat   New Zealand
# 1    Match 2    Sri Lanka      Bat     Sri Lanka
# 2    Match 3    Australia      Bat     Australia
# 3    Match 4     Pakistan      Bat      Pakistan
# 4    Match 5    Australia    Field     Australia
# 5    Match 6     Pakistan      Bat      Pakistan
# 6    Match 7     Zimbabwe      Bat      Zimbabwe
# 7    Match 8        Kenya      Bat     Sri Lanka
# 8    Match 9     Pakistan      Bat      Pakistan
# 9   Match 10     Zimbabwe      Bat   New Zealand
# 10  Match 11    Sri Lanka      Bat           NaN
# 11  Match 12        Kenya      Bat        Canada
# 12  Match 13  New Zealand      Bat   New Zealand
# 13  Match 14     Zimbabwe    Field     Sri Lanka
# 14  Match 15       Canada    Field   New Zealand
# 15  Match 16    Australia      Bat     Australia
# 16  Match 17     Zimbabwe      Bat      Pakistan
# 17  Match 18       Canada      Bat     Australia
# 18  Match 19    Sri Lanka      Bat     Sri Lanka
# 19  Match 20    Australia      Bat      Pakistan
# 20  Match 21     Zimbabwe      Bat      Zimbabwe

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = "Yes", "No"
sizes = [100-52.38, 52.38]
explode = (0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
gbp = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Group B Standings.xlsx")
gbp
# Out:
#            Team  Won  Lost  No result  Points
# 0  South Africa    5     1          0      10
# 1         India    4     1          0       9
# 2       England    3     2          0       7
# 3   West Indies    3     3          0       6
# 4    Bangladesh    3     3          0       6
# 5       Ireland    2     4          0       4
# 6   Netherlands    0     6          0       0

# %%
gbs = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Group B matches.xlsx")
gbs
# Out:
#    Match no.                 Match played  1st innings score  \
# 0    Match 1          India vs Bangladesh                370
# 1    Match 2       Netherlands vs England                292
# 2    Match 3  West Indies vs South Africa                222
# 3    Match 4        Bangladesh vs Ireland                205
# 4    Match 5             India vs England                338
# 5    Match 6   West Indies vs Netherlands                330
# 6    Match 7           England vs Ireland                327
# 7    Match 8  South Africa vs Netherlands                351
# 8    Match 9    Bangladesh vs West Indies                 58
# 9   Match 10      England vs South Africa                171
# 10  Match 11             Ireland vs India                207
# 11  Match 12         Netherlands vs India                189
# 12  Match 13       West Indies vs Ireland                275
# 13  Match 14        England vs Bangladesh                225
# 14  Match 15        India vs South Africa                296
# 15  Match 16    Netherlands vs Bangladesh                160
# 16  Match 17      South Africa vs Ireland                272
# 17  Match 18       England vs West Indies                243
# 18  Match 19       Netherlands vs Ireland                306
# 19  Match 20   South Africa vs Bangladesh                284
# 20  Match 21         India vs West Indies                268
#
#     2nd innings score  Wickets fell_1  Wickets fell_2  Overs played 1  \
# 0                 283               4               9            50.0
# 1                 296               6               4            50.0
# 2                 223              10               3            47.3
# 3                 178              10              10            49.2
# 4                 338              10               8            49.5
# 5                 115               8              10            50.0
# 6                 329               8               7            50.0
# 7                 120               5              10            50.0
# 8                  59              10               1            18.5
# 9                 165              10              10            45.4
# 10                210              10               5            47.5
# 11                191              10               5            46.4
# 12                231              10              10            50.0
# 13                227              10               8            49.4
# 14                300              10               7            48.4
# 15                166              10               4            46.2
# 16                141               7              10            50.0
# 17                225              10              10            48.4
# 18                307              10               4            50.0
# 19                 78               8              10            50.0
# 20                188              10              10            49.1
#
#     Overs played 2     Stadium
# 0             50.0       Dhaka
# 1             48.4      Nagpur
# 2             42.5       Delhi
# 3             45.0       Dhaka
# 4             50.0   Bengaluru
# 5             31.3       Delhi
# 6             49.1   Bengaluru
# 7             34.2      Mohali
# 8             12.2       Dhaka
# 9             47.4     Chennai
# 10            46.0   Bengaluru
# 11            36.3       Delhi
# 12            49.0      Mohali
# 13            49.0  Chittagong
# 14            49.4      Nagpur
# 15            40.2  Chittagong
# 16            33.2     Kolkata
# 17            44.4     Chennai
# 18            47.4     Kolkata
# 19            28.0       Dhaka
# 20            43.0     Chennai

# %%
gbs["1st innings score"].describe()
# Out:
# count     21.000000
# mean     256.619048
# std       75.371398
# min       58.000000
# 25%      207.000000
# 50%      272.000000
# 75%      306.000000
# max      370.000000
# Name: 1st innings score, dtype: float64

# %%
print(np.median(gbs["1st innings score"]))
# Out:
# 272.0

# %%
density = np.array([gbs["1st innings score"]])


sns.set(rc={'figure.figsize':(15.7,6.27)})
plt.title("Density Distribuition of 1st innings scores")
sns.distplot(density, hist=True, rug=True);
# Out:
# <ipython-input-38-49b850edc78a>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(density, hist=True, rug=True);

# %%
gbs["run_rate_1"] = gbs["1st innings score"]/gbs["Overs played 1"]
gbs
# Out:
#    Match no.                 Match played  1st innings score  \
# 0    Match 1          India vs Bangladesh                370
# 1    Match 2       Netherlands vs England                292
# 2    Match 3  West Indies vs South Africa                222
# 3    Match 4        Bangladesh vs Ireland                205
# 4    Match 5             India vs England                338
# 5    Match 6   West Indies vs Netherlands                330
# 6    Match 7           England vs Ireland                327
# 7    Match 8  South Africa vs Netherlands                351
# 8    Match 9    Bangladesh vs West Indies                 58
# 9   Match 10      England vs South Africa                171
# 10  Match 11             Ireland vs India                207
# 11  Match 12         Netherlands vs India                189
# 12  Match 13       West Indies vs Ireland                275
# 13  Match 14        England vs Bangladesh                225
# 14  Match 15        India vs South Africa                296
# 15  Match 16    Netherlands vs Bangladesh                160
# 16  Match 17      South Africa vs Ireland                272
# 17  Match 18       England vs West Indies                243
# 18  Match 19       Netherlands vs Ireland                306
# 19  Match 20   South Africa vs Bangladesh                284
# 20  Match 21         India vs West Indies                268
#
#     2nd innings score  Wickets fell_1  Wickets fell_2  Overs played 1  \
# 0                 283               4               9            50.0
# 1                 296               6               4            50.0
# 2                 223              10               3            47.3
# 3                 178              10              10            49.2
# 4                 338              10               8            49.5
# 5                 115               8              10            50.0
# 6                 329               8               7            50.0
# 7                 120               5              10            50.0
# 8                  59              10               1            18.5
# 9                 165              10              10            45.4
# 10                210              10               5            47.5
# 11                191              10               5            46.4
# 12                231              10              10            50.0
# 13                227              10               8            49.4
# 14                300              10               7            48.4
# 15                166              10               4            46.2
# 16                141               7              10            50.0
# 17                225              10              10            48.4
# 18                307              10               4            50.0
# 19                 78               8              10            50.0
# 20                188              10              10            49.1
#
#     Overs played 2     Stadium  run_rate_1
# 0             50.0       Dhaka    7.400000
# 1             48.4      Nagpur    5.840000
# 2             42.5       Delhi    4.693446
# 3             45.0       Dhaka    4.166667
# 4             50.0   Bengaluru    6.828283
# 5             31.3       Delhi    6.600000
# 6             49.1   Bengaluru    6.540000
# 7             34.2      Mohali    7.020000
# 8             12.2       Dhaka    3.135135
# 9             47.4     Chennai    3.766520
# 10            46.0   Bengaluru    4.357895
# 11            36.3       Delhi    4.073276
# 12            49.0      Mohali    5.500000
# 13            49.0  Chittagong    4.554656
# 14            49.4      Nagpur    6.115702
# 15            40.2  Chittagong    3.463203
# 16            33.2     Kolkata    5.440000
# 17            44.4     Chennai    5.020661
# 18            47.4     Kolkata    6.120000
# 19            28.0       Dhaka    5.680000
# 20            43.0     Chennai    5.458248

# %%
gbs["run_rate_1"].describe()
# Out:
# count    21.000000
# mean      5.322557
# std       1.222083
# min       3.135135
# 25%       4.357895
# 50%       5.458248
# 75%       6.120000
# max       7.400000
# Name: run_rate_1, dtype: float64

# %%
print(np.median(gbs["run_rate_1"]))
# Out:
# 5.458248472505091

# %%
plt.figure(figsize=(15,10))
# sns.barplot(gbs["Stadium"],gbs["run_rate_1"]);
sns.barplot(x = 'Stadium',y = 'run_rate_1',data = gbs)
plt.show()

# %%
density = np.array([gbs["run_rate_1"]])


sns.set(rc={'figure.figsize':(15,6.27)})
plt.title("Density Distribuition of 1st innings run_rates")
sns.distplot(density, hist=True, rug=True);
# Out:
# <ipython-input-43-a51b26f20937>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(density, hist=True, rug=True);

# %%
gbs["Wickets fell_1"].describe()
# Out:
# count    21.000000
# mean      8.857143
# std       1.878449
# min       4.000000
# 25%       8.000000
# 50%      10.000000
# 75%      10.000000
# max      10.000000
# Name: Wickets fell_1, dtype: float64

# %%
plt.figure(figsize=(22,10))
plt.title("Graph of wickets fell in 1st innings")
# sns.barplot(gbs["Match no."],gbs["Wickets fell_1"]);
sns.barplot(x = 'Match no.',y = 'Wickets fell_1',data = gbs)
plt.show()

# %%
gbs["Overs played 1"].describe()
# Out:
# count    21.000000
# mean     47.395238
# std       6.778826
# min      18.500000
# 25%      47.500000
# 50%      49.400000
# 75%      50.000000
# max      50.000000
# Name: Overs played 1, dtype: float64

# %%
print(np.median(gbs["Overs played 1"]))
# Out:
# 49.4

# %%
plt.figure(figsize=(22,10))
plt.title("Graph of no. of overs played in 1st innings")
# sns.barplot(gbs["Match no."],gbs["Overs played 1"]);
sns.barplot(x = 'Match no.',y = 'Overs played 1',data = gbs)
plt.show()

# %%
gbs["2nd innings score"].describe()
# Out:
# count     21.000000
# mean     208.095238
# std       80.550546
# min       59.000000
# 25%      165.000000
# 50%      210.000000
# 75%      283.000000
# max      338.000000
# Name: 2nd innings score, dtype: float64

# %%
density = np.array([gbs["2nd innings score"]])


sns.set(rc={'figure.figsize':(15,6.27)})
plt.title("Density Distribuition of 2nd innings scores")
sns.distplot(density, hist=True, rug=True);
# Out:
# <ipython-input-50-27689a22dc3e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(density, hist=True, rug=True);

# %%
#Run rate of 2nd innings
gbs["run_rate_2"] = gbs["2nd innings score"]/gbs["Overs played 2"]
gbs
# Out:
#    Match no.                 Match played  1st innings score  \
# 0    Match 1          India vs Bangladesh                370
# 1    Match 2       Netherlands vs England                292
# 2    Match 3  West Indies vs South Africa                222
# 3    Match 4        Bangladesh vs Ireland                205
# 4    Match 5             India vs England                338
# 5    Match 6   West Indies vs Netherlands                330
# 6    Match 7           England vs Ireland                327
# 7    Match 8  South Africa vs Netherlands                351
# 8    Match 9    Bangladesh vs West Indies                 58
# 9   Match 10      England vs South Africa                171
# 10  Match 11             Ireland vs India                207
# 11  Match 12         Netherlands vs India                189
# 12  Match 13       West Indies vs Ireland                275
# 13  Match 14        England vs Bangladesh                225
# 14  Match 15        India vs South Africa                296
# 15  Match 16    Netherlands vs Bangladesh                160
# 16  Match 17      South Africa vs Ireland                272
# 17  Match 18       England vs West Indies                243
# 18  Match 19       Netherlands vs Ireland                306
# 19  Match 20   South Africa vs Bangladesh                284
# 20  Match 21         India vs West Indies                268
#
#     2nd innings score  Wickets fell_1  Wickets fell_2  Overs played 1  \
# 0                 283               4               9            50.0
# 1                 296               6               4            50.0
# 2                 223              10               3            47.3
# 3                 178              10              10            49.2
# 4                 338              10               8            49.5
# 5                 115               8              10            50.0
# 6                 329               8               7            50.0
# 7                 120               5              10            50.0
# 8                  59              10               1            18.5
# 9                 165              10              10            45.4
# 10                210              10               5            47.5
# 11                191              10               5            46.4
# 12                231              10              10            50.0
# 13                227              10               8            49.4
# 14                300              10               7            48.4
# 15                166              10               4            46.2
# 16                141               7              10            50.0
# 17                225              10              10            48.4
# 18                307              10               4            50.0
# 19                 78               8              10            50.0
# 20                188              10              10            49.1
#
#     Overs played 2     Stadium  run_rate_1  run_rate_2
# 0             50.0       Dhaka    7.400000    5.660000
# 1             48.4      Nagpur    5.840000    6.115702
# 2             42.5       Delhi    4.693446    5.247059
# 3             45.0       Dhaka    4.166667    3.955556
# 4             50.0   Bengaluru    6.828283    6.760000
# 5             31.3       Delhi    6.600000    3.674121
# 6             49.1   Bengaluru    6.540000    6.700611
# 7             34.2      Mohali    7.020000    3.508772
# 8             12.2       Dhaka    3.135135    4.836066
# 9             47.4     Chennai    3.766520    3.481013
# 10            46.0   Bengaluru    4.357895    4.565217
# 11            36.3       Delhi    4.073276    5.261708
# 12            49.0      Mohali    5.500000    4.714286
# 13            49.0  Chittagong    4.554656    4.632653
# 14            49.4      Nagpur    6.115702    6.072874
# 15            40.2  Chittagong    3.463203    4.129353
# 16            33.2     Kolkata    5.440000    4.246988
# 17            44.4     Chennai    5.020661    5.067568
# 18            47.4     Kolkata    6.120000    6.476793
# 19            28.0       Dhaka    5.680000    2.785714
# 20            43.0     Chennai    5.458248    4.372093

# %%
gbs["run_rate_2"].describe()
# Out:
# count    21.000000
# mean      4.869721
# std       1.122820
# min       2.785714
# 25%       4.129353
# 50%       4.714286
# 75%       5.660000
# max       6.760000
# Name: run_rate_2, dtype: float64

# %%
plt.figure(figsize=(15,10))
# sns.barplot(gbs['Stadium'],gbs["run_rate_2"]);
sns.barplot(x = 'Stadium',y = 'run_rate_2',data = gbs)
plt.show()

# %%
gbs["Wickets fell_2"].describe()
# Out:
# count    21.000000
# mean      7.380952
# std       2.923631
# min       1.000000
# 25%       5.000000
# 50%       8.000000
# 75%      10.000000
# max      10.000000
# Name: Wickets fell_2, dtype: float64

# %%
plt.figure(figsize=(25,10))
plt.title('Wickets fell in each match')
# sns.barplot(gbs['Match no.'],gbs["Wickets fell_2"]);
sns.barplot(x = 'Match no.',y = 'Wickets fell_2',data = gbs)
plt.show()

# %%
gbs["Overs played 2"].describe()
# Out:
# count    21.000000
# mean     41.714286
# std       9.574147
# min      12.200000
# 25%      36.300000
# 50%      45.000000
# 75%      49.000000
# max      50.000000
# Name: Overs played 2, dtype: float64

# %%
gbt = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Group B toss.xlsx")
gbt
# Out:
#    Match no.  Won the toss Decision Won the match
# 0    Match 1    Bangladesh      BAT         India
# 1    Match 2   Netherlands      BAT       England
# 2    Match 3  South Africa    FIELD  South Africa
# 3    Match 4    Bangladesh      BAT    Bangladesh
# 4    Match 5         India      BAT          Tied
# 5    Match 6   Netherlands    FIELD   West Indies
# 6    Match 7       England      BAT       Ireland
# 7    Match 8   Netherlands    FIELD  South Africa
# 8    Match 9    Bangladesh      BAT   West Indies
# 9   Match 10       England      BAT       England
# 10  Match 11         India    FIELD         India
# 11  Match 12   Netherlands      BAT         India
# 12  Match 13       Ireland    FIELD   West Indies
# 13  Match 14    Bangladesh    FIELD    Bangladesh
# 14  Match 15         India      BAT  South Africa
# 15  Match 16   Netherlands      BAT    Bangladesh
# 16  Match 17       Ireland    FIELD  South Africa
# 17  Match 18       England      BAT       England
# 18  Match 19       Ireland    FIELD       Ireland
# 19  Match 20  South Africa      BAT  South Africa
# 20  Match 21         India      BAT         India

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = "Yes", "No"
sizes = [100-42.85, 42.85]
explode = (0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
qpm = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Quarter finals.xlsx")
qpm
# Out:
#                          Match       Date                       Result  \
# 0      West Indies vs Pakistan 2011-03-23   Pakistan won by 10 wickets
# 1           Australia vs India 2011-03-24       India won by 5 wickets
# 2  New Zealand vs South Africa 2011-03-25   New Zealand won by 49 runs
# 3         England vs Sri Lanka 2011-03-26  Sri Lanka won by 10 wickets
#
#       Stadium
# 0       Dhaka
# 1  Ahemedabad
# 2       Dhaka
# 3     Colombo

# %%
qfm = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/QF-Matches.xlsx")
qfm
# Out:
#         Match   Runs scored 1  Runs scored 2  Wickets fell 1  Wickets fell 2
# 0   WI vs PAK             112            113              10               0
# 1  AUS vs IND             260            261               6               5
# 2    NZ vs SA             221            172               8               0
# 3   ENG vs SL             229            231               6               0

# %%
plt.figure(figsize=(10,10))
plt.title("Runs scored in 1st innings")
# sns.barplot(qfm['Match'],qfm[" Runs scored 1"]);
sns.barplot(x = 'Match',y = ' Runs scored 1',data = qfm)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title("Runs scored in 2nd innings")
# sns.barplot(qfm['Match'],qfm["Runs scored 2"]);
sns.barplot(x = 'Match',y = 'Runs scored 2',data = qfm)
plt.show()

# %%
ns = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/NZ vs SL.xlsx")
ns.dropna()
# Out:
#                Batsmen  Runs  Balls    4s   6s      SR
# 0       Martin Guptill  39.0   65.0   3.0  0.0   60.00
# 1     Brendon McCullum  13.0   21.0   1.0  1.0   61.00
# 2          Jesse Ryder  19.0   34.0   2.0  0.0   55.88
# 3          Ross Taylor  36.0   55.0   1.0  0.0   65.45
# 4         Scott Styris  57.0   77.0   5.0  0.0   74.02
# 5       Kane Willamson  22.0   16.0   3.0  0.0  137.50
# 6      Nathan McCullum   9.0    9.0   0.0  1.0  100.00
# 7           Jacob Oram   7.0    9.0   1.0  0.0   77.77
# 8       Daniel Vettori   3.0    3.0   0.0  0.0  100.00
# 9         Time Southee   0.0    3.0   0.0  0.0    0.00
# 10          Andy McKay   0.0    2.0   0.0  0.0    0.00
# 12       Upul Tharanga  30.0   31.0   4.0  1.0   96.77
# 13           T Dilshan  73.0   93.0  10.0  1.0   78.49
# 14    Kumar Sangakkara  54.0   79.0   7.0  1.0   68.35
# 15  Mahela Jayawardene   1.0    3.0   0.0  0.0   33.33
# 16       T Samaraweera  23.0   38.0   2.0  0.0   60.52
# 17       Chamara Silva  13.0   25.0   2.0  0.0   52.00
# 18      Angelo Mathews  14.0   18.0   1.0  1.0   77.77

# %%
plt.figure(figsize=(35,10))
plt.title("Performance of Batmsen")
# sns.barplot(ns['Batsmen'],ns["Runs"]);
sns.barplot(x = 'Batsmen',y = 'Runs',data = ns)
plt.show()

# %%
ns1 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/NZ vs SL Bowl.xlsx")

# %%
ns1["econ"] = ns1["Runs"]/ns1["Overs"]
ns1
# Out:
#             Bowler  Runs  Wickets  Overs      econ
# 0        L Malinga    55        3    9.0  6.111111
# 1         R Herath    31        1    9.0  3.444444
# 2        A Mathews    27        0    6.0  4.500000
# 3         A Mendis    35        3    9.5  3.684211
# 4          M Murli    42        2   10.0  4.200000
# 5        T Dilshan    22        1    5.0  4.400000
# 6       N McCullum    33        0    6.0  5.500000
# 7        T Southee    57        3   10.0  5.700000
# 8   Daniel Vettori    36        1   10.0  3.600000
# 9           J Oram    29        0    8.0  3.625000
# 10         A McKay    37        1    9.5  3.894737
# 11        S Styris    12        0    2.0  6.000000
# 12         J Ryder    14        0    2.0  7.000000

# %%
plt.figure(figsize=(35,10))
plt.title("Runs given by the bowlers")
# sns.barplot(ns1['Bowler'],ns1["Runs"]);
sns.barplot(x = 'Bowler',y = 'Runs',data = ns1)
plt.show()

# %%
plt.figure(figsize=(35,10))
plt.title("Economy of the bowlers")
# sns.barplot(ns1['Bowler'],ns1["econ"]);
sns.barplot(x = 'Bowler',y = 'econ',data = ns1)
plt.show()

# %%
ns2 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/SF IND BAT.xlsx")
ns2
# Out:
#         Batsman  Runs  Balls  4s  6s      SR
# 0      V Sehwag    38     25   9   0  152.00
# 1   S Tendulkar    85    115  11   0   73.91
# 2     G Gambhir    27     32   2   0   84.37
# 3       V Kohli     9     21   0   0   42.85
# 4       Y Singh     0      1   0   0    0.00
# 5      MS Dhoni    25     42   2   0   59.52
# 6       S Raina    36     39   3   0   92.30
# 7       H Singh    12     15   2   0   80.00
# 8        Z Khan     9     10   1   0   90.00
# 9       A Nehra     1      2   0   0   50.00
# 10      M Patel     0      0   0   0    0.00

# %%
plt.figure(figsize=(25,10))
plt.title("Runs scored by the batsman")
# sns.barplot(ns2['Batsman'],ns2["Runs"]);
sns.barplot(x = 'Batsman',y = 'Runs',data =ns2)
plt.show()

# %%
ns3 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/SF PAK BOWL.xlsx")
ns3
# Out:
#      Player  Wickets  Runs  Overs
# 0     U Gul        0    69      8
# 1  A Razzaq        0    14      2
# 2    W Riaz        5    46     10
# 3   S Ajmal        2    44     10
# 4  S Afridi        0    45     10
# 5  M Hafeez        1    34     10

# %%
ns4 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/SF PAK BAT.xlsx")
ns4
# Out:
#       Player  Runs  Balls  4s  6s      SR
# 0    K Akmal    19     21   3   0   90.47
# 1   M Hafeez    43     59   7   0   72.88
# 2   A Shafiq    30     39   2   0   76.92
# 3     Y Khan    13     32   0   0   40.62
# 4      M Haq    56     76   5   1   73.68
# 5    U Akmal    29     24   1   2  120.83
# 6   A Razzaq     3      9   0   0   33.33
# 7   S Afridi    19     17   1   0  111.76
# 8     W Riaz     8     14   1   0   57.14
# 9      U Gul     2      3   0   0   66.66
# 10   S Ajmal     1      5   0   0   20.00

# %%
plt.figure(figsize=(25,10))
plt.title("Runs scored by the batsman")
# sns.barplot(ns4['Player'],ns4["Runs"]);
sns.barplot(x = 'Player',y = 'Runs',data = ns4)
plt.show()

# %%
ns5 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/SF-IND-BOWL.xlsx")
ns5["econ"] = ns5["Runs"]/ns5["Overs"]
ns5
# Out:
#     Player  Overs  Runs  Wickets      econ
# 0   Z Khan    9.5    58        2  6.105263
# 1  A Nehra   10.0    33        2  3.300000
# 2  M Patel   10.0    40        2  4.000000
# 3  H Singh   10.0    43        2  4.300000
# 4  Y Singh   10.0    57        2  5.700000

# %%
slf = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/SL BAT FINAL.xlsx")
slf["SR"] = slf["Runs"]/slf["Balls"]*100
slf
# Out:
#            Player           Status  Runs  Balls  4s  6s          SR
# 0      U Tharanga  c Sehwag b Khan     2     20   0   0   10.000000
# 1       T Dilshan        b H Singh    33     49   3   0   67.346939
# 2    K Sangakkara   c Dhoni b Yuvi    48     67   5   0   71.641791
# 3   M Jayawardene          not out   103     88  13   0  117.045455
# 4   T Samaraweera    lbw b Y Singh    21     34   2   0   61.764706
# 5     C Kapugedra   c Raina b Khan     1      5   0   0   20.000000
# 6     N Kulasekra    run out Dhoni    32     30   1   1  106.666667
# 7        T Perera          not out    22      9   3   1  244.444444
# 8       L Malinga      did not bat     0      0   0   0         NaN
# 9        S Randiv      did not bat     0      0   0   0         NaN
# 10        M Murli      did not bat     0      0   0   0         NaN

# %%
plt.figure(figsize=(25,10))
plt.title("Runs scored by the batsman")
# sns.barplot(slf['Player'],slf["Runs"]);
sns.barplot(x = 'Player',y = 'Runs',data = slf)
plt.show()

# %%
ibowl = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/IND BOWL.xlsx")
ibowl["econ"] = ibowl["Runs"]/ibowl["Overs"]
ibowl
# Out:
#        Bowlers  Overs  Maidens  Runs  Wickets      econ
# 0       Z Khan     10        3    60        2  6.000000
# 1    Sreesanth      8        0    52        0  6.500000
# 2      M Patel      9        0    41        0  4.555556
# 3      H Singh     10        0    50        1  5.000000
# 4      Y Singh     10        0    49        2  4.900000
# 5  S Tendulkar      2        0    12        0  6.000000
# 6      V Kohli      1        0     6        0  6.000000

# %%
fb = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/IND BAT FINAL.xlsx")
fb
# Out:
#          Player             Status  Runs  Balls    4s   6s
# 0      V Sehwag        lbw Malinga   0.0     2.0  0.0  0.0
# 1   S Tendulkar  c Sanga b Malinga  18.0    14.0  2.0  0.0
# 2     G Gambhir           b Perera  97.0   122.0  9.0  0.0
# 3       V Kohli        c&b Dilshan  35.0    49.0  4.0  0.0
# 4      MS Dhoni            not out  91.0    79.0  8.0  2.0
# 5       Y Singh            not out  21.0    24.0  2.0  0.0
# 6       S Raina                NaN   NaN     NaN  NaN  NaN
# 7       H Singh                NaN   NaN     NaN  NaN  NaN
# 8        Z Khan                NaN   NaN     NaN  NaN  NaN
# 9       M Patel                NaN   NaN     NaN  NaN  NaN
# 10    Sreesanth                NaN   NaN     NaN  NaN  NaN

# %%
plt.figure(figsize=(25,10))
plt.title("Runs scored by the batsman")
# sns.barplot(fb['Player'],fb["Runs"]);
sns.barplot(x = 'Player',y = 'Runs',data = fb)
plt.show()

# %%
FB = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/SRI BOWL.xlsx")
FB["econ"] = FB["Runs"]/FB["Overs"]
FB
# Out:
#         Bowler  Overs  Runs  Wickets       econ
# 0    L Malinga    9.0    42        2   4.666667
# 1  N Kulasekra    8.2    64        0   7.804878
# 2     T Perera    9.0    55        1   6.111111
# 3     S Randiv    9.0    43        0   4.777778
# 4    T Dilshan    5.0    57        1  11.400000
# 5      M Murli    8.0    39        0   4.875000
